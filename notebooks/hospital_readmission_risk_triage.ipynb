# %% [markdown]
# # 30-Day Hospital Readmission Risk & Clinical Triage Predictor
# **Author:** [Arjuna Fransesco](https://github.com/ArjunaFransesco)
# **Portfolio:** [GitHub Repositories](https://github.com/ArjunaFransesco?tab=repositories)
#
# ### Overview
# EHR risk stratification, comorbidity weighting, and LightGBM classification for reducing unplanned readmissions.

# %% [markdown]
# ## 1. Data Ingestion
# Load electronic health records.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/hospital_patient_data.csv')
df.head()
